# %% [markdown]
# # 03 Explain Variables\n\nResolve variable definitions from registry first, then docs index.

# %%
from policy_data_ai.tools.api import PolicyDataRuntime\n\nruntime = PolicyDataRuntime(registry_dir="../sources_registry")

# %%
runtime.tool_explain_variable("eurostat", "une_rt_a", "value")

# %%
runtime.tool_explain_variable("worldbank", "SL.UEM.TOTL.ZS", "value")
